# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Happiness_score.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.nunique().to_frame('TOTAL GIVEN UNIQUE VALUES OF HAPPINESSS')
# Out:
#                                TOTAL GIVEN UNIQUE VALUES OF HAPPINESSS
# Country                                                            158
# Region                                                              10
# Happiness Rank                                                     157
# Happiness Score                                                    157
# Standard Error                                                     153
# Economy (GDP per Capita)                                           158
# Family                                                             158
# Health (Life Expectancy)                                           157
# Freedom                                                            158
# Trust (Government Corruption)                                      157
# Generosity                                                         158
# Dystopia Residual                                                  158

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# Country
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: count, Length: 158, dtype: int64
#
#
# Region
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: count, dtype: int64
#
#
# Happiness Rank
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: count, Length: 157, dtype: int64
#
#
# Happiness Score
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# ...

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.head(3)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204

# %%
sns.stripplot(x='Country',y='Happiness Rank',data=df)
# Out:
# <Axes: xlabel='Country', ylabel='Happiness Rank'>

# %%
sns.scatterplot(data=df, y= 'Happiness Rank', x='Country')
# Out:
# <Axes: xlabel='Country', ylabel='Happiness Rank'>

# %%
sns.distplot(df['Happiness Rank'])
# Out:
# <Axes: xlabel='Happiness Rank', ylabel='Density'>

# %%
df.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201

# %%
sns.distplot(df['Happiness Score'])
# Out:
# <Axes: xlabel='Happiness Score', ylabel='Density'>

# %%
sns.distplot(df['Economy (GDP per Capita)'])
# Out:
# <Axes: xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df['Family'])
# Out:
# <Axes: xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df['Health (Life Expectancy)'])
# Out:
# <Axes: xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(df['Freedom'])
# Out:
# <Axes: xlabel='Freedom', ylabel='Density'>

# %%
df.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201

# %%
sns.distplot(df['Trust (Government Corruption)'])
# Out:
# <Axes: xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(df['Generosity'])
# Out:
# <Axes: xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(df['Dystopia Residual'])
# Out:
# <Axes: xlabel='Dystopia Residual', ylabel='Density'>

# %%
df.plot(kind='box', subplots=True, layout=(4,6),figsize=(10,10))
# Out:
# Happiness Rank                      Axes(0.125,0.712609;0.110714x0.167391)
# Happiness Score                  Axes(0.257857,0.712609;0.110714x0.167391)
# Standard Error                   Axes(0.390714,0.712609;0.110714x0.167391)
# Economy (GDP per Capita)         Axes(0.523571,0.712609;0.110714x0.167391)
# Family                           Axes(0.656429,0.712609;0.110714x0.167391)
# Health (Life Expectancy)         Axes(0.789286,0.712609;0.110714x0.167391)
# Freedom                             Axes(0.125,0.511739;0.110714x0.167391)
# Trust (Government Corruption)    Axes(0.257857,0.511739;0.110714x0.167391)
# Generosity                       Axes(0.390714,0.511739;0.110714x0.167391)
# Dystopia Residual                Axes(0.523571,0.511739;0.110714x0.167391)
# dtype: object

# %% [markdown]
# There is presence of outliers in standard error, family,Government corruptio, Generosity and Dystopia residual

# %%
df.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201

# %% [markdown]
# # USING LABEL ENCODER TO CONVERT COUNTRY AND REGION TO NUMERICAL VALUES

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['Country']=le.fit_transform(df['Country'])

df['Region']=le.fit_transform(df['Region'])

# %%
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153      118       8             154            3.465         0.03464
# 154       13       8             155            3.340         0.03656
# 155      136       4             156            3.006         0.05015
# 156       21       8             157            2.905         0.08658
# 157      141       8             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
sns.distplot(df['Country'])
# Out:
# <Axes: xlabel='Country', ylabel='Density'>

# %%
sns.distplot(df['Region'])
# Out:
# <Axes: xlabel='Region', ylabel='Density'>

# %%
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153      118       8             154            3.465         0.03464
# 154       13       8             155            3.340         0.03656
# 155      136       4             156            3.006         0.05015
# 156       21       8             157            2.905         0.08658
# 157      141       8             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df.dtypes
# Out:
# Country                            int32
# Region                             int32
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df['Country']=df['Country'].astype(float)
df['Region']=df['Region'].astype(float)
df['Happiness Rank']=df['Happiness Rank'].astype(float)

# %%
df.dtypes
# Out:
# Country                          float64
# Region                           float64
# Happiness Rank                   float64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.corr()
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.033879 -0.022600        0.158516
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.088155  0.165040       -0.372315
# Generosity                     0.118085  0.273557       -0.160142
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# ...

# %%
plt.figure(figsize = (22,15))

sns.heatmap(df.corr(), linewidths = 0.1, fmt = '.1g', linecolor = 'black', annot = True, cmap = 'Blues_r')

plt.yticks(rotation = 0);
plt.show()

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
#Removing skewness using cubroot method

df['Standard Error']=np.cbrt(df['Standard Error'])
df['Family']=np.cbrt(df['Family'])
df['Trust (Government Corruption)']=np.cbrt(df['Trust (Government Corruption)'])
df['Dystopia Residual']=np.cbrt(df['Dystopia Residual'])

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.979748
# Economy (GDP per Capita)        -0.317575
# Family                          -3.573056
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    0.011932
# Generosity                       1.001961
# Dystopia Residual               -1.228430
# dtype: float64

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))

# %%
threshold =3

# %%
print(np.where(z>3))
# Out:
# (array([ 40,  64,  71,  73, 115, 128, 131, 147, 153, 155, 157], dtype=int64), array([ 4,  4, 11,  9,  4, 10, 11,  6, 11, 11,  6], dtype=int64))

# %%
z.iloc[153,11]
# Out:
# 3.1582973994650554

# %%
dff=df[(z<3).all(axis=1)]

# %%
dff
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0             1.0            7.587        0.324310
# 1       58.0     9.0             2.0            7.561        0.365532
# 2       37.0     9.0             3.0            7.527        0.321658
# 3      105.0     9.0             4.0            7.522        0.338540
# 4       24.0     5.0             5.0            7.427        0.328749
# ..       ...     ...             ...              ...             ...
# 150     66.0     8.0           151.0            3.655        0.371834
# 151     20.0     8.0           152.0            3.587        0.350990
# 152      0.0     7.0           153.0            3.575        0.313597
# 154     13.0     8.0           155.0            3.340        0.331896
# 156     21.0     8.0           157.0            2.905        0.442391
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
dff.shape
# Out:
# (147, 12)

# %%
print('data loss percentage:',((df.shape[0]-dff.shape[0])/dff.shape[0])*100)
# Out:
# data loss percentage: 7.482993197278912

# %%
dff
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0             1.0            7.587        0.324310
# 1       58.0     9.0             2.0            7.561        0.365532
# 2       37.0     9.0             3.0            7.527        0.321658
# 3      105.0     9.0             4.0            7.522        0.338540
# 4       24.0     5.0             5.0            7.427        0.328749
# ..       ...     ...             ...              ...             ...
# 150     66.0     8.0           151.0            3.655        0.371834
# 151     20.0     8.0           152.0            3.587        0.350990
# 152      0.0     7.0           153.0            3.575        0.313597
# 154     13.0     8.0           155.0            3.340        0.331896
# 156     21.0     8.0           157.0            2.905        0.442391
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df2=dff.drop(['Country','Region','Happiness Rank'], axis=1, inplace=True)

df2

# %% [markdown]
# The columns for Country, Region and Happiness Rank has to be dropped at this stage as it is not necessary to incoporate it in predicting the happiness score

# %%
df2

# %%
x=dff.iloc[:,1:9] 
x
# Out:
#      Standard Error  Economy (GDP per Capita)    Family  \
# 0          0.324310                   1.39651  1.105076
# 1          0.365532                   1.30232  1.119283
# 2          0.321658                   1.32548  1.108089
# 3          0.338540                   1.45900  1.099986
# 4          0.328749                   1.32629  1.097684
# ..              ...                       ...       ...
# 150        0.371834                   0.46534  0.917022
# 151        0.350990                   0.25812  0.947966
# 152        0.313597                   0.31982  0.671546
# 154        0.331896                   0.28665  0.707311
# 156        0.442391                   0.01530  0.746424
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                       0.748756
# 1                     0.94784  0.62877                       0.521036
# 2                     0.87464  0.64938                       0.784910
# ...

# %% [markdown]
# The above data is the independent variables

# %%
y=dff.iloc[:,0]

y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 150    3.655
# 151    3.587
# 152    3.575
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 147, dtype: float64

# %% [markdown]
# The above is the happiness score which is the target variables or dependent variables

# %%
dff
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)    Family  \
# 0              7.587        0.324310                   1.39651  1.105076
# 1              7.561        0.365532                   1.30232  1.119283
# 2              7.527        0.321658                   1.32548  1.108089
# 3              7.522        0.338540                   1.45900  1.099986
# 4              7.427        0.328749                   1.32629  1.097684
# ..               ...             ...                       ...       ...
# 150            3.655        0.371834                   0.46534  0.917022
# 151            3.587        0.350990                   0.25812  0.947966
# 152            3.575        0.313597                   0.31982  0.671546
# 154            3.340        0.331896                   0.28665  0.707311
# 156            2.905        0.442391                   0.01530  0.746424
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30,random_state=45)

# %%
x_train
# Out:
#      Standard Error  Economy (GDP per Capita)    Family  \
# 132        0.360319                   0.42250  0.961060
# 86         0.365032                   0.92053  1.003203
# 135        0.352150                   0.54649  0.879767
# 37         0.338191                   1.29098  1.024771
# 46         0.344766                   1.24461  0.985710
# ..              ...                       ...       ...
# 70         0.415959                   1.00761  0.995045
# 99         0.321174                   0.82819  1.091561
# 32         0.369651                   0.91861  1.074389
# 130        0.394294                   0.01604  0.743704
# 138        0.405791                   0.67866  0.871932
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 132                   0.23402  0.49309                       0.386776
# 86                    0.74836  0.20107                       0.296894
# 135                   0.40064  0.35571                       0.428250
# ...

# %%
x_train.shape
# Out:
# (102, 8)

# %%
y_test.shape
# Out:
# (45,)

# %%
x_test.shape
# Out:
# (45, 8)

# %%
y_train.shape
# Out:
# (102,)

# %%
y_test.shape
# Out:
# (45,)

# %%
LR=LogisticRegression()

# %%
dff.dtypes
# Out:
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
LR.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 LR.fit(x_train,y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1215, in LogisticRegression.fit(self, X, y, sample_weight)
#    1205     _dtype = [np.float64, np.float32]
#    1207 X, y = self._validate_data(
#    1208     X,
#    1209     y,
#    (...)
#    1213     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1214 )
# ...

# %% [markdown]
# # PLEASE NOTE THAT TIME COULD NOT PERMEAT ME TO FINISH THE GIVEN WORK. HOPEFULLY I WILL BE GIVEN ENOUGH TIME TO CONCLUDE ON THIS PROJECT.
